# %% [markdown]
# ## Edit or detete participant fields
#
# Notebook used to do batch edits or deletions of participant's fields

# %%
#%load_ext autoreload
# %autoreload
from oss_hugo.OSS_Participant import OSS_Participant
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS
from oss_hugo.OSS_GSheet_Data import OSS_GSheet_Data

# %%
fields_to_delete = ['night_day','eventbrite_id','funded_who','night_room','regonline','pre-summit',
                     'sponsored_by','venue','villa']
hugo.df_participants()[fields_to_delete].tail()
# Out:
#     night_day eventbrite_id funded_who  night_room  regonline pre-summit  \
# 122       NaN          None        NaN         NaN        NaN        NaN
# 123       NaN          None        NaN         NaN        NaN        NaN
# 124       NaN          None        NaN         NaN        NaN        NaN
# 125       NaN          None        NaN         NaN        NaN        NaN
# 126       NaN          None        NaN         NaN        NaN        NaN
#
#     sponsored_by venue  villa
# 122          NaN   NaN    NaN
# 123          NaN   NaN    NaN
# 124          NaN   NaN    NaN
# 125          NaN   NaN    NaN
# 126          NaN   NaN    NaN

# %%
# %autoreload
fields_to_delete = ['night_day','eventbrite_id','funded_who','night_room','regonline','pre-summit',
                     'sponsored_by','venue','villa']

md_participants = hugo.md_files_participants()
for md_participant in md_participants:
    participant     = OSS_Participant(md_participant)
    for field_to_delete in fields_to_delete:
        participant.delete_field(field_to_delete)
    participant.save()    
    

"removed {0} fields from {1} files".format(len(fields_to_delete), len(md_participants))
# Out:
# 'removed 9 fields from 126 files'

# %%
hugo.df_participants().columns
# Out:
# Index(['chapter_leader', 'company', 'email', 'facebook', 'featured', 'image',
#        'job_title', 'layout', 'linkedin', 'night_where', 'notes', 'pre_summit',
#        'project_leader', 'role', 'sessions', 'status', 'title', 'tracks',
#        'travel-from', 'travel_from', 'twitter', 'type', 'website',
#        'working_sessions'],
#       dtype='object')

# %%
hugo.df_participants()[['title','chapter_leader']]
# Out:
#                       title chapter_leader
# 0             Brett Crawley
# 1                  EJ Quinn
# 2             Lauren Chiesa
# 3             Hardik Parekh            NaN
# 4          Philippe De Ryck
# 5         John Ellingsworth
# 6                 Kim Wuyts
# 7           Ashraf Aboukass
# 8            Michael Madsen
# 9                 Gabor Pek
# 10                 Tom Ling
# 11
# 12       Harold Blankenship
# 13           Francisco Novo            NaN
# 14            Brian Johnson
# 15         Claudio Camerino            NaN
# 16             Zuhal Vargun
# 17            Sven Schleier
# 18           Jeroen Beckers
# 19            Lars Svensson
# 20               Sara Davis
# 21      Steven van der Baan
# 22            Scott Hayward
# 23         Paulino Calderon   Riviera Maya
# 24                      NaN            NaN
# 25             George Glass
# 26            Roberto Pérez
# 27         Ashleigh Eastway
# 28             Mike McCamon
# 29            Marco Mancini
# ..                      ...            ...
# 96        Jannik Hollenbach            NaN
# 97           Sherif Mansour            NaN
# 98           David Cervigni
# 99               Jim Manico
# 100         Adrian Winckles      Cambridge
# 101         Carlos Holguera            NaN
# 102             Andra Lezza
# 103         Felipe Zipitria        Uruguay
# 104            Didar Gelici            NaN
# 105           Sam Stepanyan            NaN
# 106        Bjoern Kimminich            NaN
# 107  Sebastien Deleersnyder            NaN
# 108          Steven Wierckx            NaN
# 109           Khaled Fattal
# 110        Jeroen Willemsen            NaN
# 111               Jon Hawes            NaN
# 112          Christoph Jung            NaN
# 113             Tash Norris            NaN
# 114              Dinis Cruz            NaN
# 115           Yasmin Martin            NaN
# 116             Jemma Davis            NaN
# 117            Maeve Scarry            NaN
# 118           Sonya Moisset            NaN
# 119           James Wharton            NaN
# 120          Simon Pavillon            NaN
# 121        David James-Roll
# 122             Chris Allen
# 123             Mario Platt
# 124             Paul Davies
# 125            Phil Huggins
#
# [126 rows x 2 columns]

# %%
gsheet=OSS_GSheet_Data()

# %%
df_gsheet = gsheet.df_participants_onsite()

# %%
df_gsheet[df_gsheet['Chapter Leader'] != '']
# Out:
#     Accommodation Chapter Leader Company                       Days  \
# 1             Yes      WiaLondon          [Mon, Tue, Wed, Thu, Fri]
# 9             Yes        Belgium  Toreon  [Mon, Tue, Wed, Thu, Fri]
# 49            Yes        Belgium     PWC  [Mon, Tue, Wed, Thu, Fri]
# 69            Yes        Uruguay          [Mon, Tue, Wed, Thu, Fri]
# 97            Yes        Morocco          [Mon, Tue, Wed, Thu, Fri]
# 98            Yes         London          [Mon, Tue, Wed, Thu, Fri]
# 102           Yes      Cambridge          [Mon, Tue, Wed, Thu, Fri]
# 103           Yes   Riviera Maya          [Mon, Tue, Wed, Thu, Fri]
# 107            No         London                              [Thu]
#
#               ID Location                    Name                Nights  \
# 1      OSS_19__2   Onsite           Lauren Chiesa  [Mon, Tue, Wed, Thu]
# 9     OSS_19__10   Onsite  Sebastien Deleersnyder  [Mon, Tue, Wed, Thu]
# 49    OSS_19__50   Onsite             Bart De Win  [Mon, Tue, Wed, Thu]
# 69    OSS_19__70   Onsite         Felipe Zipitria  [Mon, Tue, Wed, Thu]
# 97    OSS_19__98   Onsite       Azzeddine Ramrami  [Mon, Tue, Wed, Thu]
# 98    OSS_19__99   Onsite             Andra Lezza  [Mon, Tue, Wed, Thu]
# 102  OSS_19__103   Onsite         Adrian Winckles  [Mon, Tue, Wed, Thu]
# 103  OSS_19__104   Onsite        Paulino Calderon  [Mon, Tue, Wed, Thu]
# 107  OSS_19__108   Onsite           Sam Stepanyan                    []
#
#     Page On website Payment Status  \
# 1               Yes           Paid
# 9               Yes
# 49              Yes
# 69              Yes
# 97              Yes
# 98              Yes
# 102             Yes
# 103             Yes
# 107             Yes
#
#                                       Project Leader          Skills/Topics  \
# 1
# 9                                         OWASP SAMM  SAMM, Threat Modeling
# 49                                        OWASP SAMM
# 69                                                                     Hugo
# 97                                         CSRFGuard
# 98
# 102  Application Security Curriculum, OWASP Honeypot
# 103                                   OWASP IoT Goat
# 107
#
#     Sponsor
# 1
# 9
# 49
# 69    OWASP
# 97    OWASP
# 98    OWASP
# 102   OWASP
# 103   OWASP
# 107   OWASP

# %%
df_gsheet[df_gsheet['Project Leader'] != '']
# Out:
#     Accommodation Chapter Leader                      Company  \
# 9             Yes        Belgium                       Toreon
# 10            Yes                                      Toreon
# 13            Yes                 Kühne + Nagel (AG & Co.) KG
# 25             No                                       OWASP
# 42             No
# 49            Yes        Belgium                          PWC
# 52            Yes                                       Xebia
# 64            Yes
# 97            Yes        Morocco
# 100           Yes
# 102           Yes      Cambridge
# 103           Yes   Riviera Maya
#
#                           Days           ID Location                    Name  \
# 9    [Mon, Tue, Wed, Thu, Fri]   OSS_19__10   Onsite  Sebastien Deleersnyder
# 10   [Mon, Tue, Wed, Thu, Fri]   OSS_19__11   Onsite          Steven Wierckx
# 13   [Mon, Tue, Wed, Thu, Fri]   OSS_19__14   Onsite        Bjoern Kimminich
# 25                  [Tue, Wed]   OSS_19__26   Onsite          Simon Bennetts
# 42   [Mon, Tue, Wed, Thu, Fri]   OSS_19__43   Onsite     Steven van der Baan
# 49   [Mon, Tue, Wed, Thu, Fri]   OSS_19__50   Onsite             Bart De Win
# 52   [Mon, Tue, Wed, Thu, Fri]   OSS_19__53   Onsite        Jeroen Willemsen
# 64   [Mon, Tue, Wed, Thu, Fri]   OSS_19__65   Onsite           Sven Schleier
# 97   [Mon, Tue, Wed, Thu, Fri]   OSS_19__98   Onsite       Azzeddine Ramrami
# 100  [Mon, Tue, Wed, Thu, Fri]  OSS_19__101   Onsite              Jim Manico
# 102  [Mon, Tue, Wed, Thu, Fri]  OSS_19__103   Onsite         Adrian Winckles
# 103  [Mon, Tue, Wed, Thu, Fri]  OSS_19__104   Onsite        Paulino Calderon
#
#                    Nights Page On website Payment Status  \
# 9    [Mon, Tue, Wed, Thu]             Yes
# 10   [Mon, Tue, Wed, Thu]             Yes
# 13   [Mon, Tue, Wed, Thu]             Yes           Paid
# 25                     []             Yes           Paid
# 42                     []             Yes           Paid
# 49   [Mon, Tue, Wed, Thu]             Yes
# 52   [Mon, Tue, Wed, Thu]             Yes           Paid
# 64   [Mon, Tue, Wed, Thu]             Yes           Paid
# 97   [Mon, Tue, Wed, Thu]             Yes
# 100  [Mon, Tue, Wed, Thu]             Yes
# 102  [Mon, Tue, Wed, Thu]             Yes
# 103  [Mon, Tue, Wed, Thu]             Yes
#
#                                         Project Leader          Skills/Topics  \
# 9                                           OWASP SAMM  SAMM, Threat Modeling
# 10                               OWASP Threat Modeling        Threat modeling
# 13                                     OWASP Juiceshop
# 25                                           OWASP ZAP
# 42                              OWASP Capture The Flag
# 49                                          OWASP SAMM
# 52                 OWASP Mobile Security Testing Guide
# 64                 OWASP Mobile Security Testing Guide
# 97                                           CSRFGuard
# 100  OWASP Proactive Controls, OWASP Cheatsheet Ser...
# 102    Application Security Curriculum, OWASP Honeypot
# 103                                     OWASP IoT Goat
#
#        Sponsor
# 9
# 10
# 13
# 25
# 42   DevSecCon
# 49
# 52
# 64       OWASP
# 97       OWASP
# 100      OWASP
# 102      OWASP
# 103      OWASP
