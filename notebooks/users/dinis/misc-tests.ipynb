# %%
#%load_ext autoreload
# %autoreload
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS
hugo = API_Hugo_OSS()
#df_gsheet = hugo.gsheet_data().df_participants_onsite(True)
#hugo.gsheet_data().data_participants_onsite(reload)

# %%
#%load_ext autoreload
# %autoreload
from oss_hugo.OSS_Schedule import OSS_Schedule
schedule = OSS_Schedule()
df_sessions_participants = schedule.df_sessions_registered_participants()
df_sessions_participants
# Out:
#                                                                                        title  \
# 9    Securing the CI Pipeline
# 4    Agile Practices for Security Teams
# 8    DevSecOps Maturity Model (DSOMM)
# 48   Real world Chaos Engineering
# 11   How to scale Threat Modeling.
# 5    Creating Appsec metrics and visualisation
# 6    Integrating Security Tools in the SDL
# 70   State and future of threat modeling
# 73   Using Wardley Maps on SOC
# 80   Using graphs for GDPR mappings and visualisations
# 17   Application Security Verification Standard
# 67   Towards a unified way of describing threat models
# 16   SAMMv2 Measurement Model
# 7    DevSecOps
# 20   Secrets Management
# 71   Customising the Chaos Engineering Toolkit
# 10   Zap - How to use it
# 3    Securing Kubernete's hosted APIs
# 86   Using Threat Models for GDPR
# 79   From Threat Modeling to DevSecOps metrics
# 12   Scaling API Security
# 61   SAMMv2 working session - Governance
# 60   SAMM DevOps Guidance
# 51   Juice Shop Hack'n'Code II
# 59   SAMM Round Table
# 55   Juice Shop Round Table
# 58   SAMM - Best Practices
# 57   SAMM Introduction
# 56   Juice Shop Release Night
# 54   Juice Shop Challenge Refactoring
# 63   SAMMv2 working session - Implementation
# 53   Juice Shop Hack'n'Code IV
# 52   Juice Shop Hack'n'Code III
# 99   Customising the Chaos Toolkit
# 62   SAMMv2 working session - Design
# 64   SAMMv2 working session - Verification
# 65   SAMMv2 working session - Operations
# 66   SAMMv2 Establish the Document Model
# 69   SOC Monitoring Visualisation
# 72   Cell based Structures for Security
# 96   GDPR Appropriate Security Controls
# 50   Juice Shop Hack'n'Code I
# 77   Using Cynefin Framework making strategic security decisions
# 78   Lightweight privacy threat modeling using LINDDUN
# 81   Cyber Insurance
# 95   OWASP Collective Defence Cluster (CDC)
# 91   Coordinating functions within a PST organisation
# 88   Ask me anything (AMA) on GDPR
# 76   Introduction to Cynefin Framework (Training Session)
# 45   Mobile Security Testing Guide onboarding
# 89   OWASP Collective Defence Cluster (CDC) - two years on
# 106  Restructure session
# 24   Creating a Steady-State Hypothesis
# 22   Describe different ways of implementing TM in agile organisations
# 21   ZAP working session - automation
# 113  Using Wardley Maps and Cynefin for Security
# 112  Climatic Patterns and Using Doctrine
# 111  Mapping boot camp
# 18   Owasp Testing Guide v5
# 26   Create a Slack bot in Python
# 40   Writing security tests to confirm vulnerabilities and fixes
# 105  Creating content session
# 43   OWASP Mobile Security Testing Guide 101
# 13   Creating a Security Champions network
# 2    Dealing with Security Findings in the Enterprise
# 93   OWASP SAMM Tooling
# 94   SAMM benchmarking
# 97   Hands on Chaos Experiments
# 92   How to scale Threat Modeling
# 121  JIRA Risk Workflow
# 123  Web Application Honeypot
# 120  Writing Akamai rulesF
# 119  Incident handling with DarkTrace
# 122  Using The Hive for Incident Response
# 100  Akamai WAF & Ruleset
# 118  Lessons learned from public bug bounties programmes
# 117  European GDPR variations
# 101  AWS WAF for DDoS Mitigation
# 115  Share your Threat Models diagrams and create a Book
# 98   Hands-on GDPR Patterns
# 114  Cyber Insurances
# 110  secureCodeBox - How to improve your CI/CD pipeline with automated security tests
# 109  CISO
# 108  PSD2 and GDPR
# 107  Securing Serverless applications
# 104  Application Security Curriculum Project
# 103  Web Honeypot Project
# 90   Third Party Due Diligence
# 102  Adding CRS3 and Pixi to CircleCI pipeline
# 116  GDPR Compliance what does it mean?
# 0    OWASP SAMM
# 87   Cyber Risk Modeling
# 29   Using maps to define how to capture, detect and prevent 6 real-world security incidents
# 35   Federated Login with Social Platforms Threat Modeling Cheat Sheet
# 34   How to Threat Model Features with Questionnaires
# 33   Docker and Kubernetes Threat Modeling Cheat Sheet
# 32   Thinking in Graphs
# 31   Creation of Security Buttons
# 30   Back to the future with Threat Modeling
# 28   Gamifying Security Dashboards
# 85   Creating an iOS build pipeline with security checks
# 27   A long successful career in IT (women in tech)
# 25   Owasp Cloud Security Workshop (BETA)
# 23   Track Introductions
# 19   API Threat Modeling Cheat Sheet
# 15   SAMM DevSecOps Version
# 14   Juice Shop 101
# 36   Azure Security Features, Just a Few
# 37   Threat model guide
# 38   Crossing the river by feeling the stones
# 39   Threat Model training through Gamification
# 41   Using Jira to handle Incident Response - simulations
# 42   Using AI and ML for incident response
# 44   Mobile Basic Security Testing and Reverse Engineering
# 46   Android and iOS Security Enhancements and Crackme Apps
# 47   Mobile AppSec Verification Standard (MASVS)
# 49   Hacking ML Applications
# 1    Serverless
# 68   Dealing with DevSecOps Findings
# 74   Using User Story Mapping for effective communication
# 75   Cynefin Framework for Security
# 82   Owasp Top 5 Machine Learning risks
# 83   Azure Serverless for security
# 84   AWS Lambda Security
# 124  Wardley Maps for Security
#
#      participants_count  \
# 9    11
# 4    10
# 8    8
# 48   7
# 11   7
# 5    6
# 6    6
# 70   5
# 73   5
# 80   5
# 17   5
# 67   4
# 16   4
# 7    4
# 20   4
# 71   4
# 10   3
# 3    3
# 86   3
# 79   3
# 12   3
# 61   2
# 60   2
# 51   2
# 59   2
# 55   2
# 58   2
# 57   2
# 56   2
# 54   2
# 63   2
# 53   2
# 52   2
# 99   2
# 62   2
# 64   2
# 65   2
# 66   2
# 69   2
# 72   2
# 96   2
# 50   2
# 77   2
# 78   2
# 81   2
# 95   2
# 91   2
# 88   2
# 76   2
# 45   2
# 89   2
# 106  2
# 24   2
# 22   2
# 21   2
# 113  2
# 112  2
# 111  2
# 18   2
# 26   2
# 40   2
# 105  2
# 43   2
# 13   2
# 2    2
# 93   1
# 94   1
# 97   1
# 92   1
# 121  1
# 123  1
# 120  1
# 119  1
# 122  1
# 100  1
# 118  1
# 117  1
# 101  1
# 115  1
# 98   1
# 114  1
# 110  1
# 109  1
# 108  1
# 107  1
# 104  1
# 103  1
# 90   1
# 102  1
# 116  1
# 0    1
# 87   1
# 29   1
# 35   1
# 34   1
# 33   1
# 32   1
# 31   1
# 30   1
# 28   1
# 85   1
# 27   1
# 25   1
# 23   1
# 19   1
# 15   1
# 14   1
# 36   1
# 37   1
# 38   1
# 39   1
# 41   1
# 42   1
# 44   1
# 46   1
# 47   1
# 49   1
# 1    1
# 68   1
# 74   1
# 75   1
# 82   1
# 83   1
# 84   1
# 124  1
#
#                                                                                                                                                                                 participants
# 9    [Francisco Novo, Claudio Camerino, Sven Schleier, Foteini Karantoni, Rafael Jimenez, Jean-Jacques MOIROUX, Sean Siford, Martin Rock-Evans, Dominik de Smit, Tony Richards, Andra Lezza]
# 106  [Carlos Holguera, Jeroen Willemsen]
# 24   [Sara Davis, Adrian Winckles]
# 22   [Sven Schleier, Tony Richards]
# 21   [Sven Schleier, Dominik de Smit]
# 113  [Dinis Cruz, Phil Huggins]
# 112  [Dinis Cruz, Phil Huggins]
# 111  [Dinis Cruz, Phil Huggins]
# 18   [Claudio Camerino, Nick Drage]
# 26   [Sara Davis, Felipe Zipitria]
# 40   [Sara Davis, Sean Siford]
# 105  [Carlos Holguera, Jeroen Willemsen]
# 43   [Paulino Calderon, Carlos Holguera]
# 13   [Claudio Camerino, Dominik de Smit]
# 2    [Francisco Novo, Rafael Jimenez]
# 93   [Pat Duarte]
# 94   [Pat Duarte]
# 97   [Adrian Winckles]
# 92   [Irene Michlin]
# 121  [Simon Pavillon]
# 123  [Simon Pavillon]
# 120  [Simon Pavillon]
# 119  [Simon Pavillon]
# 122  [Simon Pavillon]
# 100  [Adrian Winckles]
# 118  [Simon Pavillon]
# 117  [Simon Pavillon]
# 101  [Adrian Winckles]
# 115  [Yasmin Martin]
# 98   [Adrian Winckles]
# 114  [Yasmin Martin]
# 110  [Dinis Cruz]
# 109  [Didar Gelici]
# 108  [Didar Gelici]
# 107  [Felipe Zipitria]
# 104  [Adrian Winckles]
# 103  [Adrian Winckles]
# 90   [Tony Richards]
# 102  [Adrian Winckles]
# 116  [Simon Pavillon]
# 0    [Hardik Parekh]
# 87   [Tony Richards]
# 29   [Sara Davis]
# 35   [Sara Davis]
# 34   [Sara Davis]
# 33   [Sara Davis]
# 32   [Sara Davis]
# 31   [Sara Davis]
# 30   [Sara Davis]
# 28   [Sara Davis]
# 85   [Dominik de Smit]
# 27   [Sara Davis]
# 25   [Sara Davis]
# 23   [Sara Davis]
# 19   [Claudio Camerino]
# 15   [Claudio Camerino]
# 14   [Claudio Camerino]
# 36   [Sara Davis]
# 37   [Sara Davis]
# 38   [Sara Davis]
# 39   [Sara Davis]
# 41   [Sara Davis]
# 42   [Sara Davis]
# 44   [Paulino Calderon]
# 46   [Paulino Calderon]
# 47   [Paulino Calderon]
# 49   [Paulino Calderon]
# 1    [Hardik Parekh]
# 68   [Foteini Karantoni]
# 74   [Jean-Jacques MOIROUX]
# 75   [Nick Drage]
# 82   [Sean Siford]
# 83   [Martin Rock-Evans]
# 84   [Dominik de Smit]
# 124  [Phil Huggins]

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)

from oss_hugo.OSS_Schedule import OSS_Schedule
schedule    = OSS_Schedule()

#df_sessions = schedule.sessions_mapped_by_size()

# %%
df_sessions = hugo.df_sessions()
df_sessions_organizers  = df_sessions[['title','organizers']].dropna()
df_sessions_organizers['organizers_count'] = df_sessions_organizers['organizers'].apply(lambda x: len (x))

#df_sessions_organizers

# %%
df_merge = df_sessions_organizers.merge(df_sessions_participants)
df_merge['total_count'] = df_merge['participants_count'] + df_merge['organizers_count']
df_merge = df_merge.sort_values(['participants_count','organizers_count'], ascending=False)

df_merge = df_merge.reset_index(drop=True)
qgrid.show_grid(df_merge)
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
len(df_sessions_organizers), len(df_sessions_participants)
# Out:
# (104, 125)

# %%
# %autoreload
df_sessions = hugo.df_sessions()

#df_sessions['organizers'] = df_sessions['organizers'].apply(lambda x: x.split(',') if type(x) is str else x)
a = df_sessions['type']

# %%
a.value_counts()
# Out:
# working-session    78
# user-session       19
# track              8
# keynote            1
# json               1
# Name: type, dtype: int64
