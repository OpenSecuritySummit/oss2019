# %%
#%load_ext autoreload
# %autoreload
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS
hugo = API_Hugo_OSS()
#df_gsheet = hugo.gsheet_data().df_participants_onsite(True)
#hugo.gsheet_data().data_participants_onsite(reload)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)

from oss_hugo.OSS_Schedule import OSS_Schedule
schedule    = OSS_Schedule()

#df_sessions = schedule.sessions_mapped_by_size()

# %%
df_sessions = hugo.df_sessions()

# %%
df_sessions[['title','participants']].dropna()
# Out:
#                                                            title  \
# 17   Wardley Maps for Security
# 18   Using Wardley maps on SOC
# 19   Simon Session 1
# 20   Cell based Structures for Security
# 22   Simon Session 2
# 34   How to scale Threat Modeling.
# 37   State and future of threat modeling
# 40   SAMMv2 - Threat Modeling
# 42   Using graphs for GDPR mappings and visualisations
# 47   Creating Appsec metrics and visualisation
# 54   DevSecOps Maturity Model (DSOMM)
# 59   Mobile Security Testing Guide onboarding
# 60   Android and iOS Security Enhancements and Crackme Apps
# 61   Creating an iOS build pipeline with security checks
# 62   Mobile Basic Security Testing and Reverse Engineering
# 75   Introduction to Cynefin Framework (Training Session)
# 76   Using Cynefin Framework making strategic security decisions
# 78   Using Wardley Maps and Cynefin for Security
# 79   Cyber Risk Modeling
# 88   SAMM user session - Introduction
# 89   SAMM user session - Round-table
# 90   SAMM - Tooling
# 91   SAMM - Outreach program
# 92   SAMM - Measurement model
# 93   SAMM - Parallel editing
# 94   SAMM - Alignment with other OWASP projects
# 95   SAMM - SAMM benchmarking
# 96   SAMM - Model Challenges
# 97   SAMM - Any Other Business
# 98   SAMM - Model discussions
# 99   SAMM - Alignment with other OWASP projects
# 100  SAMM - Parallel editing
# 101  SAMM - Parallel editing
# 102  SAMM - Editing agreements and parallel editing
# 103  SAMM - Alignment with other OWASP projects
# 104  SAMM - DevOps guidance
# 105  SAMM - Model Challenges
# 106  SAMM - Outreach program
# 107  SAMM - Outreach wrap-up
# 108  SAMM - Agile guidance
# 110  SAMM - Model discussions
# 111  SAMM - Alignment with Threat Modeling
# 112  SAMM - Parallel editing
# 113  SAMM - Planning and Roadmap
# 114  SAMM - SAMM documents and parallel editing
# 115  SAMM - Measurement model
#
#                                                                        participants
# 17   [Phil Huggins]
# 18   [Dinis Cruz, Jemma Davis-Smith, James Wharton, Phil Huggins]
# 19   [Phil Huggins]
# 20   [Phil Huggins]
# 22   [Phil Huggins]
# 34   [Irene Michlin]
# 37   [Irene Michlin]
# 40   [you ?]
# 42   [Mario Platt, Jim Newman]
# 47   [Jim Newman]
# 54   [Mario Platt]
# 59   [Sven Schleier]
# 60   Jeroen Willemsen, Sven Schleier, Abderrahmane AFTAHI (remote), Carlos Holguera
# 61   Sven Schleier
# 62   [Abderrahmane AFTAHI (remote)]
# 75   [Dinis Cruz]
# 76   [Dinis Cruz]
# 78   [Phil Huggins, Dinis Cruz]
# 79   [Tony Richards]
# 88   [you ?]
# 89   [you ?]
# 90   [you ?]
# 91   [you ?]
# 92   [you ?]
# 93   [you ?]
# 94   [you ?]
# 95   [you ?]
# 96   [you ?]
# 97   [you ?]
# 98   [you ?]
# 99   [you ?]
# 100  [you ?]
# 101  [you ?]
# 102  [you ?]
# 103  [you ?]
# 104  [you ?]
# 105  [you ?]
# 106  [you ?]
# 107  [you ?]
# 108  [you ?]
# 110  [you ?]
# 111  [you ?]
# 112  [you ?]
# 113  [you ?]
# 114  [you ?]
# 115  [you ?]
