# %% [markdown]
# ## Diff of Participants between GSheet and Hugo
#
# This view shows the current diff/gaps between both data sources

# %% [markdown]
# ### Users only in GSheet

# %%
df_both = hugo.df_merged_gsheet_and_hugo_data()

def filter(row):
    return row.get('GSheet') is True and row.get('Hugo') is not True

df_both[df_both.apply(filter,axis=1)]
# Out:
#                      Name company                                   Company  \
# 83         Colin Domoney                                     Createk Design
# 84        Nessim Kisserli
# 85             John Dileo
# 86         Hardik Parekh                                              OWASP
# 87       Simon Pavillion                                           Photobox
# 88           George Glass                                          Photobox
# 89           David Jensen                                          Photobox
# 90              Dan Ashby                                          Photobox
# 91    Steven van der Baan
# 92              Emma Fang                                         dunnhumby
# 93                  DSC-5
# 94                  DSC-6
# 95       Carlos Holguera                                            escrypt
# 96         Yan Kravchenko                                             OWASP
# 97          Simon Wardley                                          Photobox
# 98           Robert Grace                          JeMarketing Services Ltd
# 99           Pedro Dantas          Ministry of External Relations of Brazil
# 100          Zuhal Vargun                                      Mimecast Ltd
# 101        Florian Buetow                                      Mimecast Ltd
# 102     Foteini Karantoni                                      Mimecast Ltd
# 103  Jean-Jacques Moiroux                                      Mimecast Ltd
# 104         Brett Crawley                                      Mimecast Ltd
# 105    Christopher Dobson                                      Mimecast Ltd
# 106        Xavier Delgado              Interpartner Assistance Servicios SA
# 107         Roberto Pérez
# 108       Patricia Duarte
# 109    Deepak Subramanian                                       All Set For
# 110        Jeroen Beckers                                        NVISO CVBA
# 111           Sarah Clark
# 112         Scott Hayward
# 113        Hwee Ching Neo
# 114         David English
# 115         Brian Johnson
# 116           Karen Navas
# 117      Ashleigh Eastway
# 118         Felix Kariuki
# 119     Rebecca Ditchburn
# 120          Michael Duff
# 121           Peter Hicks
# 122          Colin Lobley
# 123         Jill McDonald
# 124              EJ Quinn
# 125          Mike McCamon                                             OWASP
# 126    Harold Blankenship                                             OWASP
# 127          Emily Berman                                             OWASP
# 128             Gabor Pek                                            Avatao
# 129          Zsolt Kalman                                            Avatao
# 130      Wouter de Meijer                            Worth Internet Systems
# 131       Mustafa Kasmani
# 132     Azzeddine Ramrami
# 133     John Ellingsworth
# 134      Ashraf Aboukass                                          Schroders
# 135     Roger Comastorres
# 136          Cybil Colaco
# 137         Alicia Barnes                                          Photobox
# 138         Adrian Taylor                                          Photobox
# 139       Pravinder Arora
# 140         Marco Mancini
# 141         William Devos
#
#     Payment Status GSheet Hugo
# 83                   True
# 84            Paid   True
# 85            Paid   True
# 86                   True
# 87            Paid   True
# 88            Paid   True
# 89            Paid   True
# 90            Paid   True
# 91            Paid   True
# 92            Paid   True
# 93            Paid   True
# 94            Paid   True
# 95                   True
# 96                   True
# 97            Paid   True
# 98            Paid   True
# 99            Paid   True
# 100           Paid   True
# 101           Paid   True
# 102           Paid   True
# 103           Paid   True
# 104           Paid   True
# 105           Paid   True
# 106           Paid   True
# 107           Paid   True
# 108                  True
# 109           Paid   True
# 110           Paid   True
# 111           Paid   True
# 112           Paid   True
# 113           Paid   True
# 114           Paid   True
# 115           Paid   True
# 116           Paid   True
# 117           Paid   True
# 118           Paid   True
# 119           Paid   True
# 120           Paid   True
# 121           Paid   True
# 122           Paid   True
# 123           Paid   True
# 124           Paid   True
# 125                  True
# 126                  True
# 127                  True
# 128           Paid   True
# 129           Paid   True
# 130           Paid   True
# 131                  True
# 132                  True
# 133                  True
# 134           Paid   True
# 135                  True
# 136           Paid   True
# 137           Paid   True
# 138           Paid   True
# 139           Paid   True
# 140           Paid   True
# 141                  True

# %% [markdown]
# ### Users only in Hugo

# %%
df_both = hugo.df_merged_gsheet_and_hugo_data()

def filter(row):
    return row.get('GSheet') is not True and row.get('Hugo') is True

df_both[df_both.apply(filter,axis=1)]
# Out:
#                     Name                   company Company Payment Status  \
# 1          Hardik Parekh                    Splunk
# 3        Ann-Marie Grace  JeMarketing Services Ltd
# 18            John DiLeo              Orion Health
# 20        Andy Cleveland
# 22        Goher Mohammad
# 26          Andre Rainho
# 27  Jean-Jacques MOIROUX                  Mimecast
# 30         Colin Domoney
# 32       Nassim Kisserli
# 47        David Cervigni
# 50       Carlos Holguera              ESCRYPT GmbH
# 56  Joris Van den Broeck                    Toreon
# 58         Thomas Heyman                    Toreon
# 60      Francois Raynaud                 DevSecCon
# 61         Khaled Fattal                 MLi Group
# 65      Fernanda Almeida               Photobox GS
# 66        Manuel Almeida               Photobox GS
# 74        Vasil Buraliev
# 75        Simon Pavillon               Photobox GS
# 77           Chris Allen
# 80             Stu Hirst            PhotoBox Group
# 81           Paul Davies                   Harrods
#
#    GSheet  Hugo
# 1          True
# 3          True
# 18         True
# 20         True
# 22         True
# 26         True
# 27         True
# 30         True
# 32         True
# 47         True
# 50         True
# 56         True
# 58         True
# 60         True
# 61         True
# 65         True
# 66         True
# 74         True
# 75         True
# 77         True
# 80         True
# 81         True

# %% [markdown]
# ### Explore Data (all Data)
#
# the Data Grid below is a great way to explore and filter the data

# %%
hugo.qgrid_merged_gsheet_and_hugo_data()
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
|
