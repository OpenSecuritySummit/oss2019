# %% [markdown]
# ## remove emails

# %%
#%load_ext autoreload
#%autoreload
from oss_hugo.OSS_GSheet_Data import OSS_GSheet_Data
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS
from oss_hugo.OSS_Participant import OSS_Participant

# %%
# %autoreload
data = OSS_GSheet_Data()
hugo = API_Hugo_OSS()

# %%
#grid = hugo.qgrid_participants(['title','email'])
df_gsheet = data.df_participants_onsite(['Name','Chapter Leader'])
df_chapters = df_gsheet[df_gsheet['Chapter Leader'] != '']#[['Name','Chapter Leader']].reset_index(drop=True)
df_chapters
# Out:
#                        Name Chapter Leader
# 1             Lauren Chiesa      WiaLondon
# 9    Sebastien Deleersnyder        Belgium
# 49              Bart De Win        Belgium
# 69          Felipe Zipitria        Uruguay
# 97        Azzeddine Ramrami        Morocco
# 98              Andra Lezza         London
# 102         Adrian Winckles      Cambridge
# 103        Paulino Calderon   Riviera Maya
# 107           Sam Stepanyan         London

# %%
# %autoreload

gsheet = OSS_GSheet_Data()
hugo   = API_Hugo_OSS()

df = hugo.df_field('chapter_leader').set_index('title')

# %%
# Out:
# 'Belgium'

# %%
#hugo.df_participants().columns.to_list()

# %%
# %autoreload
hugo = API_Hugo_OSS()
#participants = hugo.participants_oss()
participants = hugo.participants(return_oss_participants=True)
for name in names:
    print(name, participants.get(name).field('project_leader'))

print('-----')
# Out:
# Lauren Chiesa
# Sebastien Deleersnyder None
# Bart De Win
# Felipe Zipitria
# Azzeddine Ramrami
# Andra Lezza
# Adrian Winckles Web Honeypot & Application Security Curriculum Project
# Paulino Calderon IoT Goat
# Sam Stepanyan None
# -----

# %%
hugo.df_participants()[['title','chapter_leader']]
#hugo.qgrid_participants()
# Out:
#                       title chapter_leader
# 0             Brett Crawley
# 1                  EJ Quinn
# 2             Lauren Chiesa
# 3             Hardik Parekh            NaN
# 4          Philippe De Ryck
# 5         John Ellingsworth
# 6                 Kim Wuyts
# 7           Ashraf Aboukass
# 8            Michael Madsen
# 9                 Gabor Pek
# 10                 Tom Ling
# 11
# 12       Harold Blankenship
# 13           Francisco Novo            NaN
# 14            Brian Johnson
# 15         Claudio Camerino            NaN
# 16             Zuhal Vargun
# 17            Sven Schleier
# 18           Jeroen Beckers
# 19            Lars Svensson
# 20               Sara Davis
# 21      Steven van der Baan
# 22            Scott Hayward
# 23         Paulino Calderon   Riviera Maya
# 24             George Glass
# 25            Roberto Pérez
# 26         Ashleigh Eastway
# 27             Mike McCamon
# 28            Marco Mancini
# 29             Artem Vasiuk
# ..                      ...            ...
# 96        Jannik Hollenbach            NaN
# 97           Sherif Mansour            NaN
# 98           David Cervigni
# 99               Jim Manico
# 100         Adrian Winckles      Cambridge
# 101         Carlos Holguera            NaN
# 102             Andra Lezza
# 103         Felipe Zipitria        Uruguay
# 104            Didar Gelici            NaN
# 105           Sam Stepanyan            NaN
# 106        Bjoern Kimminich            NaN
# 107  Sebastien Deleersnyder            NaN
# 108          Steven Wierckx            NaN
# 109           Khaled Fattal
# 110        Jeroen Willemsen            NaN
# 111               Jon Hawes            NaN
# 112          Christoph Jung            NaN
# 113             Tash Norris            NaN
# 114              Dinis Cruz            NaN
# 115           Yasmin Martin            NaN
# 116             Jemma Davis            NaN
# 117            Maeve Scarry            NaN
# 118           Sonya Moisset            NaN
# 119           James Wharton            NaN
# 120          Simon Pavillon            NaN
# 121        David James-Roll
# 122             Chris Allen
# 123             Mario Platt
# 124             Paul Davies
# 125            Phil Huggins
#
# [126 rows x 2 columns]
