# %% [markdown]
# ## remove emails

# %%
#%load_ext autoreload
#%autoreload
from oss_hugo.OSS_GSheet_Data import OSS_GSheet_Data
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

# %%
# %autoreload
data = OSS_GSheet_Data()
hugo = API_Hugo_OSS()

# %%
hugo.df_participants()
# Out:
#      chapter-leader chapter_leader                       company  \
# 0               NaN
# 1               NaN
# 2               NaN           None                          None
# 3               NaN            NaN                        Splunk
# 4               NaN           None                          None
# 5               NaN
# 6               NaN           None                          None
# 7               NaN
# 8               NaN           None       Scalepoint Technologies
# 9               NaN
# 10              NaN           None                          None
# 11              NaN
# 12              NaN
# 13              NaN            NaN                  The Workshop
# 14              NaN
# 15              NaN            NaN                  The Workshop
# 16              NaN
# 17              NaN           None                          None
# 18              NaN
# 19              NaN           None                          None
# 20              NaN           None     Centerprise International
# 21              NaN
# 22              NaN
# 23              NaN   Riviera Maya                        Websec
# 24              NaN            NaN                           NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ..              ...            ...                           ...
# 96              NaN            NaN                 iteratec GmbH
# 97              NaN            NaN                          None
# 98              NaN           None                          None
# 99              NaN           None                          None
# 100             NaN      Cambridge      Anglia Ruskin University
# 101             NaN            NaN                  ESCRYPT GmbH
# 102             NaN           None                          None
# 103             NaN        Uruguay                           NaN
# 104             NaN            NaN                          None
# 105             NaN            NaN                          None
# 106             NaN            NaN  KUEHNE + NAGEL (AG & Co.) KG
# 107             NaN            NaN                        Toreon
# 108             NaN            NaN                        Toreon
# 109             NaN           None                     MLi Group
# 110             NaN            NaN                         Xebia
# 111             NaN            NaN                PhotoBox Group
# 112             NaN            NaN                   Photobox GS
# 113             NaN            NaN                PhotoBox Group
# 114             NaN            NaN                PhotoBox Group
# 115             NaN            NaN                      Photobox
# 116             NaN            NaN      JeMarketing Services Ltd
# 117             NaN            NaN                PhotoBox Group
# 118             NaN            NaN                PhotoBox Group
# 119             NaN            NaN                   Photobox GS
# 120             NaN            NaN                   Photobox GS
# 121             NaN           None                          None
# 122             NaN           None                          None
# 123             NaN           None                          None
# 124             NaN           None                       Harrods
# 125             NaN           None                          None
#
#                               email       eventbrite_id facebook featured  \
# 0                                                                     NaN
# 1                                                                     NaN
# 2                              None                 NaN     None      NaN
# 3           hardikkparekh@yahoo.com                None     None      NaN
# 4                              None                 NaN     None      NaN
# 5                                                                     NaN
# 6                              None                 NaN     None      NaN
# 7                                                                     NaN
# 8                              None                 NaN     None      NaN
# 9                                                                     NaN
# 10                             None                 NaN     None      NaN
# 11                                                                    NaN
# 12                                                                    NaN
# 13                 fjnovo@gmail.com                 NaN      NaN      NaN
# 14                                                                    NaN
# 15           camerinorama@gmail.com                 NaN      NaN      NaN
# 16                                                                    NaN
# 17                             None                None     None      NaN
# 18                                                                    NaN
# 19                             None                 NaN     None      NaN
# 20                             None                None     None      NaN
# 21                                                                    NaN
# 22                                                                    NaN
# 23   paulino.calderonpale@owasp.org                 NaN     None      NaN
# 24                              NaN                 NaN      NaN      NaN
# 25                                                                    NaN
# 26                                                                    NaN
# 27                                                                    NaN
# 28                                                                    NaN
# 29                                                                    NaN
# ..                              ...                 ...      ...      ...
# 96      jannik.hollenbach@owasp.org                 NaN      NaN      NaN
# 97                             None                None     None      NaN
# 98                             None                None     None      NaN
# 99                             None                None     None      NaN
# 100      adrian.wincklesa@owasp.org                 NaN      NaN      NaN
# 101                            None                None     None      NaN
# 102                            None                None     None      NaN
# 103       felipe.zipitria@owasp.org                None     None      NaN
# 104              didadida@gmail.com  didadida@gmail.com     None      NaN
# 105                            None                None     None      NaN
# 106      bjoern.kimminich@owasp.org                 NaN      NaN      NaN
# 107                  seba@owasp.org                 NaN      NaN      NaN
# 108              swierkcx@gmail.com                 NaN      NaN      NaN
# 109                   kf@mligrp.com                None     None      NaN
# 110      jeroen.willemsen@owasp.org                None     None      NaN
# 111                            None                 NaN      NaN      NaN
# 112                            None                None     None      NaN
# 113                            None                 NaN      NaN      NaN
# 114            dinis.cruz@owasp.org                 NaN      NaN      NaN
# 115                            None                None     None      NaN
# 116                            None                 NaN      NaN      NaN
# 117                            None                 NaN      NaN      NaN
# 118                            None                 NaN      NaN      NaN
# 119                            None                None     None      NaN
# 120                            None                None     None      NaN
# 121                            None                None     None      NaN
# 122                            None                None     None      NaN
# 123                            None                None     None      NaN
# 124                            None                None     None      NaN
# 125                            None                None     None      NaN
#
#     funded_who                                              image  \
# 0          NaN
# 1          NaN
# 2          NaN                                               None
# 3          NaN                                               None
# 4          NaN                                               None
# 5          NaN
# 6          NaN                                               None
# 7          NaN
# 8          NaN                                               None
# 9          NaN
# 10         NaN                                               None
# 11         NaN
# 12         NaN
# 13         NaN  https://pbs.twimg.com/profile_images/378800000...
# 14         NaN
# 15         NaN  https://avatars2.githubusercontent.com/u/31473...
# 16         NaN
# 17         NaN  https://pbs.twimg.com/profile_images/848871453...
# 18         NaN
# 19         NaN                                               None
# 20         NaN                                                NaN
# 21         NaN
# 22         NaN
# 23         NaN  https://www.blackhat.com/us-16/presenters/head...
# 24         NaN                                                NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ..         ...                                                ...
# 96         NaN  https://pbs.twimg.com/profile_images/111639953...
# 97         NaN                                                NaN
# 98         NaN  https://media.licdn.com/dms/image/C5603AQEkMCq...
# 99         NaN  https://media.licdn.com/dms/image/C5603AQFILbi...
# 100        NaN  https://avatars1.githubusercontent.com/u/92044...
# 101        NaN                                               None
# 102        NaN  https://media.licdn.com/dms/image/C5603AQGBt1q...
# 103        NaN  https://avatars1.githubusercontent.com/u/30120...
# 104        NaN  https://media.licdn.com/dms/image/C4D03AQG7GcL...
# 105        NaN                                                NaN
# 106        NaN  https://raw.githubusercontent.com/bkimminich/p...
# 107    sponsor  https://pbs.twimg.com/profile_images/425208323...
# 108    sponsor  https://pbs.twimg.com/profile_images/582556334...
# 109        NaN  https://media.licdn.com/dms/image/C5103AQH2U_o...
# 110        NaN  https://pages.xebia.com/hs-fs/hubfs/Unknown.jp...
# 111        NaN  https://media.licdn.com/dms/image/C4D03AQHR_46...
# 112        NaN                                               None
# 113        NaN  https://media.licdn.com/dms/image/C5603AQGA6zG...
# 114        NaN  https://pbs.twimg.com/profile_images/552850030...
# 115        NaN                                               None
# 116        NaN  https://media.licdn.com/dms/image/C5603AQEA207...
# 117        NaN  https://media.licdn.com/dms/image/C5603AQEdopy...
# 118        NaN  https://pbs.twimg.com/profile_images/112138476...
# 119        NaN                                                NaN
# 120        NaN                                               None
# 121        NaN  https://media.licdn.com/dms/image/C5603AQEhiJA...
# 122        NaN  https://media.licdn.com/dms/image/C4E03AQG6VOy...
# 123        NaN  https://media.licdn.com/dms/image/C4D03AQGPVVF...
# 124        NaN  https://media.licdn.com/dms/image/C5603AQE6Kj1...
# 125        NaN  https://pbs.twimg.com/profile_images/111159984...
#
#                   job-title  ...                   title  tracks  \
# 0                       NaN  ...           Brett Crawley     NaN
# 1                       NaN  ...                EJ Quinn     NaN
# 2                       NaN  ...           Lauren Chiesa     NaN
# 3                       NaN  ...           Hardik Parekh     NaN
# 4                       NaN  ...        Philippe De Ryck     NaN
# 5                       NaN  ...       John Ellingsworth     NaN
# 6                       NaN  ...               Kim Wuyts     NaN
# 7                       NaN  ...         Ashraf Aboukass     NaN
# 8                       NaN  ...          Michael Madsen     NaN
# 9                       NaN  ...               Gabor Pek     NaN
# 10                      NaN  ...                Tom Ling     NaN
# 11                      NaN  ...                             NaN
# 12                      NaN  ...      Harold Blankenship     NaN
# 13                      NaN  ...          Francisco Novo     NaN
# 14                      NaN  ...           Brian Johnson     NaN
# 15                      NaN  ...        Claudio Camerino     NaN
# 16                      NaN  ...            Zuhal Vargun     NaN
# 17                      NaN  ...           Sven Schleier     NaN
# 18                      NaN  ...          Jeroen Beckers     NaN
# 19                      NaN  ...           Lars Svensson     NaN
# 20                      NaN  ...              Sara Davis     NaN
# 21                      NaN  ...     Steven van der Baan     NaN
# 22                      NaN  ...           Scott Hayward     NaN
# 23                      NaN  ...        Paulino Calderon     NaN
# 24                      NaN  ...                     NaN     NaN
# 25                      NaN  ...            George Glass     NaN
# 26                      NaN  ...           Roberto Pérez     NaN
# 27                      NaN  ...        Ashleigh Eastway     NaN
# 28                      NaN  ...            Mike McCamon     NaN
# 29                      NaN  ...           Marco Mancini     NaN
# ..                      ...  ...                     ...     ...
# 96                      NaN  ...       Jannik Hollenbach     NaN
# 97                      NaN  ...          Sherif Mansour     NaN
# 98                      NaN  ...          David Cervigni     NaN
# 99                      NaN  ...              Jim Manico     NaN
# 100                     NaN  ...         Adrian Winckles     NaN
# 101                     NaN  ...         Carlos Holguera     NaN
# 102                     NaN  ...             Andra Lezza     NaN
# 103                     NaN  ...         Felipe Zipitria     NaN
# 104                     NaN  ...            Didar Gelici     NaN
# 105                     NaN  ...           Sam Stepanyan     NaN
# 106                     NaN  ...        Bjoern Kimminich     NaN
# 107                     NaN  ...  Sebastien Deleersnyder     NaN
# 108                     NaN  ...          Steven Wierckx     NaN
# 109                     NaN  ...           Khaled Fattal     NaN
# 110                     NaN  ...        Jeroen Willemsen     NaN
# 111                     NaN  ...               Jon Hawes     NaN
# 112                     NaN  ...          Christoph Jung     NaN
# 113                     NaN  ...             Tash Norris     NaN
# 114                     NaN  ...              Dinis Cruz     NaN
# 115                     NaN  ...           Yasmin Martin  [GDPR]
# 116                     NaN  ...             Jemma Davis     NaN
# 117                     NaN  ...            Maeve Scarry     NaN
# 118  Senior AppSec Engineer  ...           Sonya Moisset     NaN
# 119                     NaN  ...           James Wharton     NaN
# 120                     NaN  ...          Simon Pavillon     NaN
# 121                     NaN  ...        David James-Roll     NaN
# 122                     NaN  ...             Chris Allen     NaN
# 123                     NaN  ...             Mario Platt     NaN
# 124                     NaN  ...             Paul Davies     NaN
# 125                     NaN  ...            Phil Huggins     NaN
#
#         travel-from             travel_from                         twitter  \
# 0               NaN
# 1               NaN
# 2              None                     NaN                            None
# 3               NaN  San Francisco, CA, USA                     hkparekh100
# 4              None                     NaN                            None
# 5               NaN
# 6              None                     NaN                            None
# 7               NaN
# 8           Denmark                     NaN                            None
# 9               NaN
# 10             None                     NaN                            None
# 11              NaN
# 12              NaN
# 13       Malaga, ES                     NaN                      frank_novo
# 14              NaN
# 15              NaN           Bracknell, UK                          clazba
# 16              NaN
# 17              NaN               Singapore  https://twitter.com/bsd_daemon
# 18              NaN
# 19             None                     NaN                            None
# 20              NaN          United Kingdom                            None
# 21              NaN
# 22              NaN
# 23           Mexico                     NaN                       calderpwn
# 24              NaN                     NaN                             NaN
# 25              NaN
# 26              NaN
# 27              NaN
# 28              NaN
# 29              NaN
# ..              ...                     ...                             ...
# 96              NaN                     NaN                          j12934
# 97              NaN                    None                            None
# 98              NaN                    None                      DavCervSec
# 99              NaN                    None                        manicode
# 100             NaN               Cambridge                     botflowking
# 101             NaN                    None                            None
# 102             NaN                  London                    ALL_Sec_geek
# 103             NaN                 Uruguay                            None
# 104             NaN              Earlsfield                         DGelici
# 105             NaN                    None                            None
# 106             NaN                     NaN                      bkimminich
# 107             NaN                    None                        sebadele
# 108             NaN                    None                     ihackforfun
# 109             NaN                  London                       kf_MLiGrp
# 110             NaN                    None  https://twitter.com/commjoenie
# 111             NaN                     NaN                            None
# 112             NaN                    None                            None
# 113             NaN                     NaN                     TashJNorris
# 114             NaN                     NaN                       DinisCruz
# 115            None                     NaN                            None
# 116             NaN                     NaN                            None
# 117             NaN                     NaN                            None
# 118  United Kingdom                     NaN                    sonyamoisset
# 119             NaN                    None                            None
# 120             NaN                    None                            None
# 121             NaN                    None                            None
# 122             NaN                    None                            None
# 123             NaN                    None                        madplatt
# 124             NaN                    None                            None
# 125             NaN                    None                          oracuk
#
#             type                    venue villa  \
# 0    participant                      NaN   NaN
# 1    participant                      NaN   NaN
# 2    participant                      NaN   NaN
# 3    participant                      NaN   NaN
# 4    participant                      NaN   NaN
# 5    participant                      NaN   NaN
# 6    participant                      NaN   NaN
# 7    participant                      NaN   NaN
# 8    participant                      NaN   NaN
# 9    participant                      NaN   NaN
# 10   participant                      NaN   NaN
# 11   participant                      NaN   NaN
# 12   participant                      NaN   NaN
# 13   participant                      NaN   NaN
# 14   participant                      NaN   NaN
# 15   participant                      NaN   NaN
# 16   participant                      NaN   NaN
# 17   participant                      NaN   NaN
# 18   participant                      NaN   NaN
# 19   participant                      NaN   NaN
# 20   participant  Mon, Tue, Wed, Thu, Fri   NaN
# 21   participant                      NaN   NaN
# 22   participant                      NaN   NaN
# 23   participant                      NaN   NaN
# 24          json                      NaN   NaN
# 25   participant                      NaN   NaN
# 26   participant                      NaN   NaN
# 27   participant                      NaN   NaN
# 28   participant                      NaN   NaN
# 29   participant                      NaN   NaN
# ..           ...                      ...   ...
# 96   participant  Mon, Tue, Wed, Thu, Fri   NaN
# 97   participant  Mon, Tue, Wed, Thu, Fri   NaN
# 98   participant                      NaN   NaN
# 99   participant                 Wed, Thu   NaN
# 100  Participant  Mon, Tue, Wed, Thu, Fri   NaN
# 101  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 102  participant                      NaN   NaN
# 103  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 104  participant                      NaN   NaN
# 105  participant                      Fri   NaN
# 106  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 107  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 108  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 109  participant                      NaN   NaN
# 110  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 111  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 112  participant                 Wed, Thu   NaN
# 113  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 114  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 115  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 116  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 117  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 118  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 119  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 120  participant  Mon, Tue, Wed, Thu, Fri   NaN
# 121  participant                      NaN   NaN
# 122  participant                      NaN   NaN
# 123  participant                      NaN   NaN
# 124  participant                      NaN   NaN
# 125  participant                      NaN   NaN
#
#                                website working-sessions
# 0                                                   NaN
# 1                                                   NaN
# 2                                 None              NaN
# 3                                 None              NaN
# 4                                 None              NaN
# 5                                                   NaN
# 6                                 None              NaN
# 7                                                   NaN
# 8                                 None              NaN
# 9                                                   NaN
# 10                                None              NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                 NaN              NaN
# 14                                                  NaN
# 15                                 NaN              NaN
# 16                                                  NaN
# 17                                None              NaN
# 18                                                  NaN
# 19                                None              NaN
# 20                                None              NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                    calderonpale.com              NaN
# 24                                 NaN              NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ..                                 ...              ...
# 96                                 NaN              NaN
# 97                                None              NaN
# 98                                None              NaN
# 99               https://manicode.com/              NaN
# 100                               None              NaN
# 101                               None              NaN
# 102                               None              NaN
# 103                               None              NaN
# 104                               None              NaN
# 105                               None              NaN
# 106               https://kimminich.de              NaN
# 107                                NaN              NaN
# 108                                NaN              NaN
# 109                https://mligrp.biz/              NaN
# 110                               None              NaN
# 111    https://pbx-group-security.com/              NaN
# 112                               None              NaN
# 113    https://pbx-group-security.com/              NaN
# 114          http://blog.diniscruz.com              NaN
# 115                               None              NaN
# 116     https://www.jemarketing.co.uk/              NaN
# 117                               None              NaN
# 118    https://pbx-group-security.com/              NaN
# 119                               None              NaN
# 120                               None              NaN
# 121                               None              NaN
# 122                               None              NaN
# 123                               None              NaN
# 124                               None              NaN
# 125  http://blog.blackswansecurity.com              NaN
#
# [126 rows x 39 columns]

# %%
hugo.df_participants().columns.to_list()
# Out:
# ['chapter_leader',
#  'company',
#  'email',
#  'eventbrite_id',
#  'facebook',
#  'featured',
#  'funded_who',
#  'image',
#  'job-title',
#  'job_title',
#  'layout',
#  'linkedin',
#  'night_day',
#  'night_room',
#  'night_where',
#  'notes',
#  'pre-summit',
#  'pre_summit',
#  'project_leader',
#  'regonline',
#  'role',
#  'sessions',
#  'slack_id',
#  'sponsored_by',
#  'status',
#  'ticket',
#  'title',
#  'tracks',
#  'travel-from',
#  'travel_from',
#  'twitter',
#  'type',
#  'venue',
#  'villa',
#  'website',
#  'working-sessions',
#  'working_sessions']

# %%
hugo.qgrid_participants()
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…
