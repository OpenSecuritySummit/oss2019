# %% [markdown]
# ## Sessions - All Registrations

# %%
# %load_ext autoreload
# %autoreload
from oss_hugo.OSS_Schedule import OSS_Schedule
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
schedule = OSS_Schedule()
hugo     = API_Hugo_OSS()

df_sessions_participants = schedule.df_sessions_registered_participants()
df_sessions = hugo.df_sessions()
df_sessions_organizers  = df_sessions[['title','organizers']].dropna()
df_sessions_organizers['organizers_count'] = df_sessions_organizers['organizers'].apply(lambda x: len (x))

# %%
# merge both DataFrames
df_merge = df_sessions_organizers.merge(df_sessions_participants)
df_merge['total_count'] = df_merge['participants_count'] + df_merge['organizers_count']
df_merge = df_merge.sort_values(['participants_count','organizers_count'], ascending=False)

df_merge = df_merge.reset_index(drop=True)
df_merge[['title', 'total_count', 'participants_count','organizers_count','organizers','participants']]
;
# Out:
# ''

# %%
# data= df_sessions_participants.set_index('title').to_dict(orient='index')
# pd.DataFrame(data)

# df_sessions              = hugo.df_sessions()
# df_sessions_organizers   = df_sessions[['title','organizers']].dropna()
# df_sessions_participants = schedule.df_sessions_registered_participants()
by_participants          = df_sessions_participants.set_index('title').to_dict(orient='index')
by_organizers            = df_sessions_organizers  .set_index('title').to_dict(orient='index')

# %%
set(by_participants)
set(by_organizers)
all_sessions = {}
for key, value in by_participants.items():
    participants_count = value.get('participants_count')
    all_sessions[key] = { 'title'       : key                ,
                          'participants': participants_count , 
                          'organizers'  : 0                  , 
                          'total'       : participants_count }

for key, value in by_organizers.items():
    organizers_count = value['organizers_count']
    if all_sessions.get(key):
        all_sessions[key]['organizers'] =  organizers_count
        all_sessions[key]['total'     ] += organizers_count
        pass
    else:
        all_sessions[key] = { 'title'        : key              ,
                              'participants' : 0                ,
                              'organizers'   : organizers_count , 
                              'total'        : organizers_count }
                                     

            
all_sessions = pd.DataFrame(all_sessions.values())
all_sessions = all_sessions[['title','total','organizers','participants']]
all_sessions = all_sessions.sort_values(['total'], ascending=False)
all_sessions
# Out:
#                                                                   title  \
# 0    Securing the CI Pipeline
# 3    Application Security Verification Standard
# 1    Creating Appsec metrics and visualisation
# 2    Agile Practices for Security Teams
# 4    How to scale Threat Modeling
# 5    Writing security tests to confirm vulnerabilities and fixes
# 6    Secrets Management
# 7    Integrating Security Tools in the SDL
# 8    State and future of threat modeling
# 9    DevSecOps Maturity Model (DSOMM)
# 20   Dealing with DevSecOps Findings
# 14   SAMM user session - Introduction
# 11   Real world Chaos Engineering
# 13   Towards a unified way of describing threat models
# 15   ZAP working session - automation
# 33   Mapping OWASP DevSecOps Maturity Model to SAMMv2
# 10   Zap - How to use it
# 12   From Threat Modeling to DevSecOps metrics
# 26   Lightweight privacy threat modeling using LINDDUN
# 36   SAMM - Tooling
# 35   SAMM - Outreach wrap-up
# 34   SAMM - SAMM documents and parallel editing (Wed AM)
# 32   Wardley Maps for Security
# 31   SAMM user session - Round-table
# 29   SAMM - Alignment with Threat Modeling
# 23   Using Wardley Maps on SOC
# 16   Scaling API Security
# 21   Mobile Security Testing Guide onboarding
# 24   SAMM - Alignment with other OWASP projects (Fri)
# 17   OWASP Mobile Security Testing Guide 101
# 18   Customising the Chaos Engineering Toolkit
# 19   Mobile AppSec Verification Standard (MASVS)
# 45   SAMM - SAMM benchmarking
# 22   Mobile Basic Security Testing and Reverse Engineering
# 55   SAMM - Parallel editing (Thu AM)
# 46   SAMM - Editing agreements and parallel editing
# 56   SAMM - Alignment with other OWASP projects (Thu)
# 54   SAMM - Parallel editing (Tue)
# 53   SAMM - Measurement model (Mon EV)
# 52   SAMM - Model discussions (Tue)
# 51   SAMM - Measurement model (Mon PM)
# 50   SAMM - Model discussions (Wed)
# 49   SAMM - Alignment with other OWASP projects (Wed)
# 48   SAMM - Parallel editing (Wed PM)
# 47   SAMM - Outreach program (Mon)
# 58   SAMM - Parallel editing (Thu PM)
# 57   SAMM - Outreach program (Tue)
# 25   Creating a Security Champions network
# 28   Using graphs for GDPR mappings and visualisations
# 27   Wardley Mapping - Climatic Patterns and Using Doctrine
# 44   Android and iOS Security Enhancements and Crackme Apps
# 100  OWASP MSTG
# 43   Ask me anything (AMA) on GDPR
# 78   SAMM - DevOps guidance
# 77   Using Wardley Maps and Cynefin for Security
# 76   SAMM - Planning and Roadmap
# 70   SAMM - Any Other Business
# 61   Cell based Structures for Security
# 75   OWASP Application Security Curriculum Project
# 42   Third Party Due Diligence
# 30   Describe different ways of implementing TM in agile organisations
# 41   Hand's on Wardley Maps creation (Training Session)
# 40   Juice Shop Release Night
# 39   Mapping boot camp
# 38   Juice Shop Hack'n'Code
# 74   ZAP working session - the HUD
# 89   SAMM - Model Challenges (Tue)
# 92   SAMM track - Onboarding
# 87   SAMM - Agile guidance
# 93   Incremental Threat Modeling
# 85   OWASP SAMM
# 60   Security Challenges - Next step
# 79   Introduction to Wardley Maps (Training Session)
# 91   SAMMv2 - Threat Modeling
# 59   Securing Kubernete's hosted APIs
# 73   DevSecOps
# 72   ZAP working session - future plans
# 37   Share your Threat Models diagrams and create a Book
# 69   Security Challenges - An Introduction
# 68   Security Challenges - Analysis, Analogies
# 67   Juice Shop Round Table
# 66   Juice Shop Challenge Refactoring
# 65   Wardley Mapping - Coordinating functions within a PST organisation
# 64   Creating an iOS build pipeline with security checks
# 63   Using Cynefin Framework making strategic security decisions
# 62   Introduction to Cynefin Framework (Training Session)
# 90   SAMM - Model Challenges (Wed)
# 106  Threat Model Examples Project (PM-3)
# 98   OWASP HoneyPot
# 109  Threat Model Examples Project (PM-2)
# 111  Automated Threat Hunting Project Collaboration
# 81   Juice Shop 101
# 88   Cyber Risk Modeling
# 86   Creating a Threat Library
# 84   Juice Shop Contributor Onboarding
# 83   Security Challenges - Collate others' strategies and assumptions
# 104  Lightweight privacy threat modeling using LINDDUN Part II
# 71   Create a Slack bot in Python
# 110  Track closure
# 108  TM maturity
# 112  TM track introduction
# 107  How do we persist the information from the TM Slack channel?
# 105  Creating a generic diagram of a threat model
# 80   Threat Model Examples Project
# 103  Strategic Challenges
# 102  OWASP Mobile Security Testing Guide 101 (Session 2)
# 101  Mobile Security Testing Guide onboarding (Session 2)
# 99   OWASP Media Project
# 97   Wardley Maps
# 96   OWASP community-docs
# 95   Security Challenges - Analyse others
# 94   OWASP Juice Shop
# 82   SAMM - Model discussions
# 113  WAFs - Understanding and measuring how they behave
#
#      total  organizers  participants
# 0    16     1           15
# 3    12     1           11
# 1    12     1           11
# 2    12     1           11
# 4    11     0           11
# 5    11     1           10
# 6    10     1           9
# 7    10     1           9
# 8    9      1           8
# 9    9      1           8
# 20   8      3           5
# 14   8      2           6
# 11   8      1           7
# 13   7      1           6
# 15   7      1           6
# 33   7      3           4
# 10   7      0           7
# 12   7      1           6
# 26   6      2           4
# 36   6      2           4
# 35   6      2           4
# 34   6      2           4
# 32   6      2           4
# 31   6      2           4
# 29   6      2           4
# 23   6      1           5
# 16   6      1           5
# 21   6      1           5
# 24   6      2           4
# 17   6      1           5
# 18   6      1           5
# 19   6      1           5
# 45   6      3           3
# 22   6      1           5
# 55   5      2           3
# 46   5      2           3
# 56   5      2           3
# 54   5      2           3
# 53   5      2           3
# 52   5      2           3
# 51   5      2           3
# 50   5      2           3
# 49   5      2           3
# 48   5      2           3
# 47   5      2           3
# 58   5      2           3
# 57   5      2           3
# 25   5      1           4
# 28   5      1           4
# 27   5      1           4
# 44   4      1           3
# 100  4      4           0
# 43   4      1           3
# 78   4      2           2
# 77   4      2           2
# 76   4      2           2
# 70   4      2           2
# 61   4      2           2
# 75   4      2           2
# 42   4      1           3
# 30   4      0           4
# 41   4      1           3
# 40   4      1           3
# 39   4      1           3
# 38   4      1           3
# 74   3      1           2
# 89   3      2           1
# 92   3      2           1
# 87   3      2           1
# 93   3      2           1
# 85   3      2           1
# 60   3      1           2
# 79   3      1           2
# 91   3      2           1
# 59   3      1           2
# 73   3      1           2
# 72   3      1           2
# 37   3      0           3
# 69   3      1           2
# 68   3      1           2
# 67   3      1           2
# 66   3      1           2
# 65   3      1           2
# 64   3      1           2
# 63   3      1           2
# 62   3      1           2
# 90   3      2           1
# 106  2      2           0
# 98   2      2           0
# 109  2      2           0
# 111  2      2           0
# 81   2      1           1
# 88   2      1           1
# 86   2      1           1
# 84   2      1           1
# 83   2      1           1
# 104  2      2           0
# 71   2      0           2
# 110  1      1           0
# 108  1      1           0
# 112  1      1           0
# 107  1      1           0
# 105  1      1           0
# 80   1      0           1
# 103  1      1           0
# 102  1      1           0
# 101  1      1           0
# 99   1      1           0
# 97   1      1           0
# 96   1      1           0
# 95   1      1           0
# 94   1      1           0
# 82   1      0           1
# 113  1      1           0

# %%
len(all_sessions) # was 123
# Out:
# 114

# %% [markdown]
# ### test: check session's titles that don't exist

# %%
#this code prints the name of sessions that exist in participant's schedule but don't match a session title
schedule = OSS_Schedule()
df_sessions_participants = schedule.df_sessions_registered_participants()
titles = sorted(df_sessions_participants['title'].to_list())
sessions = hugo.sessions_oss()

for title in titles:
    if sessions.get(title) is None:
        print(title)
# Out:
# Create a Slack bot in Python
# Describe different ways of implementing TM in agile organisations
# How to scale Threat Modeling
# SAMM - Model discussions
# Share your Threat Models diagrams and create a Book
# Threat Model Examples Project

# %%
#hugo.participants()

# %%
from oss_hugo.OSS_Participant import OSS_Participant

#hugo.qgrid_participants(['title','sessions'])
user = hugo.participants_oss()['Dinis Cruz']
user.fields()
# Out:
# ['owasp_leadership',
#  'title',
#  'type',
#  'image',
#  'project_user',
#  'project_contributor',
#  'sessions',
#  'website',
#  'job_title',
#  'company',
#  'project_leader',
#  'linkedin',
#  'status',
#  'aaa',
#  'twitter']

# %%
user.field('sessions').append('aaa')

# %%
user.field('sessions')
# Out:
# ['Using Wardley Maps on SOC',
#  'Mapping boot camp',
#  'Wardley Mapping - Coordinating functions within a PST organisation',
#  'Wardley Mapping - Climatic Patterns and Using Doctrine',
#  'Using Wardley Maps and Cynefin for Security',
#  'Introduction to Cynefin Framework (Training Session)',
#  'Using Cynefin Framework making strategic security decisions',
#  'aaa']

# %%
user.save()

# %%
oss_bot = OSS_Participant('OSS_Bot')

# %%
oss_bot.exists()
# Out:
# False

# %%
oss_bot.create()

# %%
oss_bot.exists()
# Out:
# True

# %% [markdown]
# ## Changing an user value
#
# this will show how to change it
#
# ![image](https://user-images.githubusercontent.com/656739/58750905-abdba880-848f-11e9-9af5-06a9331bea41.png)

# %%
df_sessions_organizers[df_sessions_organizers.set_index('title').index.duplicated()]
# Out:
#                             title                      organizers  \
# 64  Threat Model Examples Project  [Jonathan Marcil, Tash Norris]
#
#     organizers_count
# 64  2

# %%
# Out:
# 42

# %%
# Out:
# True
