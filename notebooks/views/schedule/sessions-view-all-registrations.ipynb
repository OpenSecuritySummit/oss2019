# %% [markdown]
# ## Sessions - All Registrations

# %%
# %load_ext autoreload
# %autoreload
from oss_hugo.OSS_Schedule import OSS_Schedule
from oss_hugo.API_Hugo_OSS import API_Hugo_OSS

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows'    , 1000)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
schedule = OSS_Schedule()
hugo     = API_Hugo_OSS()

df_sessions_participants = schedule.df_sessions_registered_participants()
df_sessions = hugo.df_sessions()
df_sessions_organizers  = df_sessions[['title','organizers']].dropna()
df_sessions_organizers['organizers_count'] = df_sessions_organizers['organizers'].apply(lambda x: len (x))

# %%
# merge both DataFrames
df_merge = df_sessions_organizers.merge(df_sessions_participants)
df_merge['total_count'] = df_merge['participants_count'] + df_merge['organizers_count']
df_merge = df_merge.sort_values(['participants_count','organizers_count'], ascending=False)

df_merge = df_merge.reset_index(drop=True)
df_merge[['title', 'total_count', 'participants_count','organizers_count','organizers','participants']]
;
# Out:
# ''

# %%
# data= df_sessions_participants.set_index('title').to_dict(orient='index')
# pd.DataFrame(data)

# df_sessions              = hugo.df_sessions()
# df_sessions_organizers   = df_sessions[['title','organizers']].dropna()
# df_sessions_participants = schedule.df_sessions_registered_participants()
by_participants          = df_sessions_participants.set_index('title').to_dict(orient='index')
by_organizers            = df_sessions_organizers  .set_index('title').to_dict(orient='index')

# %%
set(by_participants)
set(by_organizers)
all_sessions = {}
for key, value in by_participants.items():
    participants_count = value.get('participants_count')
    all_sessions[key] = { 'title'       : key                ,
                          'participants': participants_count , 
                          'organizers'  : 0                  , 
                          'total'       : participants_count }

for key, value in by_organizers.items():
    organizers_count = value['organizers_count']
    if all_sessions.get(key):
        all_sessions[key]['organizers'] =  organizers_count
        all_sessions[key]['total'     ] += organizers_count
        pass
    else:
        all_sessions[key] = { 'title'        : key              ,
                              'participants' : 0                ,
                              'organizers'   : organizers_count , 
                              'total'        : organizers_count }
                                     

            
all_sessions = pd.DataFrame(all_sessions.values())
all_sessions = all_sessions[['title','total','organizers','participants']]
all_sessions = all_sessions.sort_values(['total'], ascending=False)
all_sessions
# Out:
#                                                                   title  \
# 0    Securing the CI Pipeline
# 1    How to scale Threat Modeling
# 2    Agile Practices for Security Teams
# 3    Secrets Management
# 4    Application Security Verification Standard
# 5    State and future of threat modeling
# 6    Creating Appsec metrics and visualisation
# 7    Integrating Security Tools in the SDL
# 8    DevSecOps Maturity Model (DSOMM)
# 9    Writing security tests to confirm vulnerabilities and fixes
# 11   Towards a unified way of describing threat models
# 10   Real world Chaos Engineering
# 12   From Threat Modeling to DevSecOps metrics
# 14   ZAP working session - automation
# 15   SAMM user session - Introduction
# 16   Lightweight privacy threat modeling using LINDDUN
# 26   Mapping OWASP DevSecOps Maturity Model to SAMMv2
# 23   SAMM - Alignment with other OWASP projects (Fri)
# 49   SAMM - SAMM benchmarking
# 30   SAMM - SAMM documents and parallel editing (Wed AM)
# 29   Wardley Maps for Security
# 25   SAMM user session - Round-table
# 20   SAMM - Alignment with Threat Modeling
# 22   SAMM - Tooling
# 13   Zap - How to use it
# 19   Customising the Chaos Engineering Toolkit
# 18   Using Wardley Maps on SOC
# 17   Scaling API Security
# 44   SAMM - Model discussions (Wed)
# 45   SAMM - Parallel editing (Thu AM)
# 46   SAMM - Alignment with other OWASP projects (Wed)
# 47   SAMM - Alignment with other OWASP projects (Thu)
# 48   SAMM - Parallel editing (Thu PM)
# 51   SAMM - Model discussions (Tue)
# 50   SAMM - Outreach wrap-up
# 55   SAMM - Measurement model (Mon PM)
# 52   SAMM - Parallel editing (Tue)
# 54   SAMM - Measurement model (Mon EV)
# 42   SAMM - Parallel editing (Wed PM)
# 60   Dealing with DevSecOps Findings
# 43   SAMM - Outreach program (Tue)
# 53   SAMM - Editing agreements and parallel editing
# 41   SAMM - Outreach program (Mon)
# 27   Wardley Mapping - Climatic Patterns and Using Doctrine
# 21   Mobile Security Testing Guide onboarding
# 24   Describe different ways of implementing TM in agile organisations
# 28   Using graphs for GDPR mappings and visualisations
# 99   OWASP MSTG
# 80   Using Wardley Maps and Cynefin for Security
# 77   SAMM - Planning and Roadmap
# 76   SAMM - Any Other Business
# 75   SAMM - DevOps guidance
# 40   Creating a Security Champions network
# 56   Cell based Structures for Security
# 74   OWASP Application Security Curriculum Project
# 31   Ask me anything (AMA) on GDPR
# 34   Third Party Due Diligence
# 39   Share your Threat Models diagrams and create a Book
# 32   Mapping boot camp
# 37   Juice Shop Release Night
# 36   Juice Shop Hack'n'Code
# 35   OWASP Mobile Security Testing Guide 101
# 38   Mobile AppSec Verification Standard (MASVS)
# 33   Mobile Basic Security Testing and Reverse Engineering
# 63   Juice Shop Challenge Refactoring
# 61   Creating an iOS build pipeline with security checks
# 57   Introduction to Cynefin Framework (Training Session)
# 89   SAMM - Model Challenges (Wed)
# 88   SAMM - Model Challenges (Tue)
# 85   SAMM - Agile guidance
# 64   Juice Shop Round Table
# 58   Introduction to Wardley Maps (Training Session)
# 79   Cyber Risk Modeling
# 78   SAMMv2 - Threat Modeling
# 59   Using Cynefin Framework making strategic security decisions
# 84   OWASP SAMM
# 62   Wardley Mapping - Coordinating functions within a PST organisation
# 66   Security Challenges - An Introduction
# 72   ZAP working session - future plans
# 71   Security Challenges - Next step
# 70   Create a Slack bot in Python
# 65   Security Challenges - Analysis, Analogies
# 69   DevSecOps
# 68   Securing Kubernete's hosted APIs
# 73   ZAP working session - the HUD
# 67   Hand's on Wardley Maps creation (Training Session)
# 97   OWASP HoneyPot
# 92   Threat Model Examples Project
# 90   Android and iOS Security Enhancements and Crackme Apps
# 91   Security Challenges - Collate others' strategies and assumptions
# 83   Juice Shop 101
# 82   Juice Shop Contributor Onboarding
# 81   How do we persist the information from the TM Slack channel?
# 87   API Threat Modeling Cheat Sheet
# 86   Lightweight Privacy Threat Modelling Using LINDUN
# 93   OWASP Juice Shop
# 94   Security Challenges - Analyse others
# 95   OWASP community-docs
# 96   Wardley Maps
# 98   OWASP Media Project
# 100  Strategic Challenges
# 101  Open Session - Run over session
# 102  Threat Model
# 103  Open Session
# 104  Creating a Threat Library
# 105  WAFs - Understanding and measuring how they behave
#
#      total  organizers  participants
# 0    16     1           15
# 1    13     1           12
# 2    12     1           11
# 3    11     1           10
# 4    11     1           10
# 5    10     1           9
# 6    10     1           9
# 7    9      1           8
# 8    9      1           8
# 9    9      1           8
# 11   8      1           7
# 10   8      1           7
# 12   7      1           6
# 14   7      1           6
# 15   7      2           5
# 16   7      2           5
# 26   7      3           4
# 23   6      2           4
# 49   6      3           3
# 30   6      2           4
# 29   6      2           4
# 25   6      2           4
# 20   6      2           4
# 22   6      2           4
# 13   6      0           6
# 19   6      1           5
# 18   6      1           5
# 17   6      1           5
# 44   5      2           3
# 45   5      2           3
# 46   5      2           3
# 47   5      2           3
# 48   5      2           3
# 51   5      2           3
# 50   5      2           3
# 55   5      2           3
# 52   5      2           3
# 54   5      2           3
# 42   5      2           3
# 60   5      3           2
# 43   5      2           3
# 53   5      2           3
# 41   5      2           3
# 27   5      1           4
# 21   5      1           4
# 24   5      1           4
# 28   5      1           4
# 99   4      4           0
# 80   4      2           2
# 77   4      2           2
# 76   4      2           2
# 75   4      2           2
# 40   4      1           3
# 56   4      2           2
# 74   4      2           2
# 31   4      1           3
# 34   4      1           3
# 39   4      1           3
# 32   4      1           3
# 37   4      1           3
# 36   4      1           3
# 35   4      1           3
# 38   4      1           3
# 33   4      1           3
# 63   3      1           2
# 61   3      1           2
# 57   3      1           2
# 89   3      2           1
# 88   3      2           1
# 85   3      2           1
# 64   3      1           2
# 58   3      1           2
# 79   3      1           2
# 78   3      1           2
# 59   3      1           2
# 84   3      2           1
# 62   3      1           2
# 66   3      1           2
# 72   3      1           2
# 71   3      1           2
# 70   3      1           2
# 65   3      1           2
# 69   3      1           2
# 68   3      1           2
# 73   3      1           2
# 67   3      1           2
# 97   2      2           0
# 92   2      1           1
# 90   2      1           1
# 91   2      1           1
# 83   2      1           1
# 82   2      1           1
# 81   2      1           1
# 87   1      0           1
# 86   1      0           1
# 93   1      1           0
# 94   1      1           0
# 95   1      1           0
# 96   1      1           0
# 98   1      1           0
# 100  1      1           0
# 101  1      1           0
# 102  1      1           0
# 103  1      1           0
# 104  1      1           0
# 105  1      1           0

# %%
len(all_sessions) # was 123
# Out:
# 106

# %% [markdown]
# ### test: check session's titles that don't exist

# %%
#this code prints the name of sessions that exist in participant's schedule but don't match a session title
schedule = OSS_Schedule()
df_sessions_participants = schedule.df_sessions_registered_participants()
titles = sorted(df_sessions_participants['title'].to_list())
sessions = hugo.sessions_oss()

for title in titles:
    if sessions.get(title) is None:
        print(title)
# Out:
# Juice Shop Hack'n'Codero
# SAMM - Model discussions

# %%
#hugo.participants()

# %%
from oss_hugo.OSS_Participant import OSS_Participant

#hugo.qgrid_participants(['title','sessions'])
user = hugo.participants_oss()['Dinis Cruz']
user.fields()
# Out:
# ['owasp_leadership',
#  'title',
#  'type',
#  'image',
#  'project_user',
#  'project_contributor',
#  'sessions',
#  'website',
#  'job_title',
#  'company',
#  'project_leader',
#  'linkedin',
#  'status',
#  'aaa',
#  'twitter']

# %%
user.field('sessions').append('aaa')

# %%
user.field('sessions')
# Out:
# ['Using Wardley Maps on SOC',
#  'Mapping boot camp',
#  'Wardley Mapping - Coordinating functions within a PST organisation',
#  'Wardley Mapping - Climatic Patterns and Using Doctrine',
#  'Using Wardley Maps and Cynefin for Security',
#  'Introduction to Cynefin Framework (Training Session)',
#  'Using Cynefin Framework making strategic security decisions',
#  'aaa']

# %%
user.save()

# %%
oss_bot = OSS_Participant('OSS_Bot')

# %%
oss_bot.exists()
# Out:
# False

# %%
oss_bot.create()

# %%
oss_bot.exists()
# Out:
# True

# %% [markdown]
# ## Changing an user value
#
# this will show how to change it
#
# ![image](https://user-images.githubusercontent.com/656739/58750905-abdba880-848f-11e9-9af5-06a9331bea41.png)

# %%
oss_bot = OSS_Participant('OSS_Bot')
oss_bot

# %%
40+2
# Out:
# 42
